# %% [markdown]
# # lean-py-generator Jupyter Notebook Demo
# Generated automatically by Lean 4.

# %%
# Generated by lean-py-generator

import math
def hypotenuse(a: float, b: float) -> float:
    return math.sqrt(a ** 2 + b ** 2)
print(f"hypot(3, 4) = {hypotenuse(3.0, 4.0)}")
